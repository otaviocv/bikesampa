# %% [markdown]
# # Prototype

# %% [markdown]
# ## Introduction

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup

# %% [markdown]
# ### Parameters

# %%
data = "Takeout/E-mail/bikesampa.mbox"
subject_target = "Subject: Bike Sampa - Como foi sua viagem?"

# %%
html_open_tag = "<html>"
html_close_tag = "</html>"

# %% [markdown]
# ## Extacting data

# %% [markdown]
# ### Selecting emails with ride details

# %%
with open(data, "r") as f:
    emails = f.readlines()

# %%
i = 0
selected_emails = []
while i < len(emails):
    if subject_target in emails[i]:
        open_i = None
        close_i = None
        while open_i is None or close_i is None:
            if html_open_tag in emails[i]:
                open_i = i
            if html_close_tag in emails[i]:
                close_i = i
            i+=1
        new_email = "".join(emails[open_i:close_i+1])
        selected_emails.append(new_email)
    
    i+=1

# %%
len(selected_emails)
# Out:
# 235

# %% [markdown]
# ### Parsing html
#
# I want to extract:
# - Ride source stations
# - Ride target station
# - Ride start time
# - Ride end time
# - Ride duration

# %%
def get_info(soup):
    span_tags = soup.find_all('span')
    source_station = span_tags[0].text
    start_time = span_tags[1].text
    target_station = span_tags[2].text
    end_time = span_tags[3].text
    return (source_station, start_time, target_station, end_time)

# %%
data = []
error_list = []
for i, email in enumerate(selected_emails):
    soup = BeautifulSoup(email, 'html.parser')
    try:
        data_point = get_info(soup)
        data.append(data_point)
    except IndexError:
        print(f"Error: {i}")
        error_list.append(i)

# %%
df = pd.DataFrame(data, columns=["source_station", "start_time", "target_station", "end_time"])

# %%
df = df.applymap(lambda x: x.replace("=\n", "")
                       .replace("=C3=A7", "ç")
                       .replace("=C3=BA", "ú")
                       .replace("=C3=AD", "í")
                       .replace("=C3=A3", "ã")
                       .replace("=C3=A1", "á")
                       .replace("</span>", "").split("\n")[0])

# %%
df
# Out:
#                   source_station           start_time  \
# 0            1 - Largo da Batata  2019-05-09 09:16:52
# 1        12 - Largo de Batata II  2019-09-10 08:51:46
# 2          11 - Praça Faria Lima  2019-07-12 09:06:00
# 3        12 - Largo de Batata II  2019-04-10 09:33:10
# 4     26 - Praça Pierre Germayel  2019-06-24 19:21:58
# 5        12 - Largo de Batata II  2019-06-24 09:01:13
# 6     26 - Praça Pierre Germayel  2019-06-19 19:07:30
# 7          11 - Praça Faria Lima  2019-06-19 09:02:40
# 8                117 - Cubo Itaú  2019-06-12 17:59:33
# 9        12 - Largo de Batata II  2019-06-12 09:58:13
# 10           1 - Largo da Batata  2018-08-01 08:32:32
# 11         11 - Praça Faria Lima  2018-06-14 08:49:33
# 12         11 - Praça Faria Lima  2018-11-21 09:28:35
# 13         11 - Praça Faria Lima  2019-06-25 09:09:46
# 14         118 - Rua Júlio Diniz  2020-03-03 18:14:50
# 15    26 - Praça Pierre Germayel  2019-06-17 18:45:14
# 16               6 - Rua Manduri  2019-06-17 09:44:48
# 17       12 - Largo de Batata II  2019-06-17 09:39:42
# 18         11 - Praça Faria Lima  2018-06-28 08:38:37
# 19       12 - Largo de Batata II  2019-08-09 09:07:04
# 20       12 - Largo de Batata II  2018-07-31 09:22:00
# 21    26 - Praça Pierre Germayel  2018-12-12 18:19:41
# 22         11 - Praça Faria Lima  2018-12-12 06:53:55
